# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
df_green = pd.read_excel("Share_of_green_areas_and_green_area_per_capita_in_cities_and_urban_areas_1990_-_2020.xlsx", sheet_name = "Data")

# %%
df_green.head(15)
# Out:
#    Country or Territory Name          City Code        City Name  \
# 0                Afghanistan           AF_KABUL            Kabul
# 1                Afghanistan           AF_HERAT            Herat
# 2                Afghanistan  AF_MAZAR_E_SHARIF   Mazar-e Sharif
# 3                Afghanistan        AF_KANDAHAR         Kandahar
# 4                    Algeria          DZ_ANNABA           Annaba
# 5                    Algeria           DZ_BLIDA            Blida
# 6                    Algeria     DZ_CONSTANTINE        Qacentina
# 7                    Algeria           DZ_CHLEF            Chlef
# 8                    Algeria           DZ_BATNA            Batna
# 9                    Algeria          DZ_TIARET  Tiaret (Tihert)
# 10                    Angola          AO_HUAMBO           Huambo
# 11                    Angola           AO_LUENA            Luena
# 12                    Angola         AO_MALANJE          Malanje
# ...

# %%
df_green[df_green["SDG Region"] == "Latin America and the Caribbean"]
# Out:
#               Country or Territory Name                 City Code  \
# 14                            Argentina               AR_CLORINDA
# 15                            Argentina           AR_BUENOS_AIRES
# 16                            Argentina                AR_ROSARIO
# 17                            Argentina                 AR_ZARATE
# 18                            Argentina               AR_SAN_JUAN
# ..                                  ...                       ...
# 629                             Uruguay              UY_MALDONADO
# 630                             Uruguay             UY_MONTEVIDEO
# 631                             Uruguay                   UY_MELO
# 640  Venezuela (Bolivarian Republic of)  VE_ALTAGRACIA_DE_ORITUCO
# 662     Latin America and the Caribbean                       NaN
#
#                  City Name SDG Sub-Region                       SDG Region  \
# 14                Clorinda  South America  Latin America and the Caribbean
# ...

# %%
df_green[df_green["Country or Territory Name"] == "Latin America and the Caribbean"]
# Out:
#            Country or Territory Name City Code City Name SDG Sub-Region  \
# 662  Latin America and the Caribbean       NaN       NaN            NaN
#
#                           SDG Region  \
# 662  Latin America and the Caribbean
#
#      Average share of green area in city/urban area 1990 (%)  \
# 662                                          24.768592
#
#      Average share of green area in city/ urban area 2000 (%)  \
# 662                                          19.691444
#
#      Average share of green area in city/ urban area 2010 (%)  \
# 662                                          16.640137
#
#      Average share of green area in city/ urban area 2020 (%)  \
# 662                                          14.957582
#
#      Green area per capita 1990 (m2/person)  \
# 662                               58.286715
#
#      Green area per capita 2000 (m2/person)  \
# 662                               38.532484
#
#      Green area per capita 2010 (m2/person)  \
# ...

# %%
df_green_latin = df_green[df_green["Country or Territory Name"] == "Latin America and the Caribbean"]

# %%
df_green_latin.to_csv("Green_Share_Latin_America.csv")
